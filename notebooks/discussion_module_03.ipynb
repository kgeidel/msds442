# %%
######################################################################
# Discussion 3 - Fundamentals & Architecture of LLM-powered AI Agents
# 
# Kevin Geidel
######################################################################

from dotenv import load_dotenv
load_dotenv()

from openai import OpenAI
client = OpenAI()

def query_llm(workplace_business_domain='supplier performance management'):
    completion = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[{
            "role": "developer",
            "content": f'''Compare LangChain and LangGraph for designing LLM-based agents with memory, adaptability, and complex workflow execution in {workplace_business_domain}.

            Discuss integration considerations, handling challenges like hallucinations, and ensuring reliability in the agent design for {workplace_business_domain}.'''
        }]
    )
    response = completion.choices[0].message.content
    print(response)

# %%
query_llm('onboarding new team members to the data management and media science team')
# Out:
# When designing LLM-based agents for onboarding new team members to the data management and media science team, both LangChain and LangGraph provide powerful frameworks to facilitate this process. Both tools offer unique features that influence their suitability depending on specific needs surrounding memory, adaptability, and complex workflow execution.
#
# ### LangChain vs. LangGraph
#
# #### Overview of LangChain
# LangChain is a framework that allows developers to build applications powered by large language models (LLMs). It provides an extensive set of integrations for data sources, tools for memory management, and modular components to create conversational agents. In the context of onboarding, LangChain stands out for its adaptability and ease of creating contexts that can access and manipulate information dynamically.
#
# ...
